# %%
#import pandas library to export the data
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# use skip rows and nrows function to filter the total claimants data of Aged16+
data_all = pd.read_csv('claimants count_local authority_nomis.csv', skiprows=7,nrows=217)
data_all
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 0                                           Darlington      3520    2605
# 1                                        County Durham     14825   10275
# 2                                           Hartlepool      4415    3250
# 3                                        Middlesbrough      7195    5290
# 4                                       Northumberland      8040    5910
# ..                                                 ...       ...     ...
# 212                            Lisburn and Castlereagh      2895    2405
# 213                                Mid and East Antrim      3925    3205
# 214                                         Mid Ulster      3740    3175
# 215                             Newry, Mourne and Down      6180    5160
# 216                                Ards and North Down      4030    3570
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# ...

# %%
df= pd.DataFrame(data_all)
df
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 0                                           Darlington      3520    2605
# 1                                        County Durham     14825   10275
# 2                                           Hartlepool      4415    3250
# 3                                        Middlesbrough      7195    5290
# 4                                       Northumberland      8040    5910
# ..                                                 ...       ...     ...
# 212                            Lisburn and Castlereagh      2895    2405
# 213                                Mid and East Antrim      3925    3205
# 214                                         Mid Ulster      3740    3175
# 215                             Newry, Mourne and Down      6180    5160
# 216                                Ards and North Down      4030    3570
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# ...

# %%
# Use histogram graph to visulaise the distribution of the data. 
df.hist(bins= 50, figsize= (15,15))
plt.show()

# %%
# Take out the mean value of each year
df.mean(numeric_only=True)
# Out:
# May-13     6892.903226
# May-14     5042.188940
# May-15     3716.958525
# May-16     3595.391705
# May-17     3731.935484
# May-18     4131.105991
# May-19     5128.248848
# May-20    12264.285714
# May-21    11349.585253
# May-22     7407.949309
# dtype: float64

# %%
# find 10 largest claimants counts in May 2013
#use nlargest function to call out 10 largest value for specific column
May13_largest= df.nlargest(n=10, columns = ['May-13'])
May13_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     47370   37725
# 133                                               Kent     27030   19795
# 81                                               Essex     25300   17255
# 48                                               Leeds     24295   18525
# 189                                       Glasgow City     22825   17475
# 29                                          Lancashire     22030   16060
# 21                                          Manchester     19570   14195
# 31                                           Liverpool     19490   14985
# 45                                            Bradford     19415   15630
# 83                                             Norfolk     17175   11525
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    29840   30745   32075   35740   44565   77630   80450   64130
# ...

# %%
sns.barplot(x ='May-13', y ='local authority: county / unitary (as of April 2021)', data = May13_largest )
plt.title('Top 10 Highest Claimant Counties in 2013', size=16)
plt.xlabel('Number of Claimants', size=14)
plt.show()

# %%
May14_largest= df.nlargest(n=10, columns = ['May-14'])
May14_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     47370   37725
# 133                                               Kent     27030   19795
# 48                                               Leeds     24295   18525
# 189                                       Glasgow City     22825   17475
# 81                                               Essex     25300   17255
# 29                                          Lancashire     22030   16060
# 45                                            Bradford     19415   15630
# 31                                           Liverpool     19490   14985
# 208                                            Belfast     15990   14210
# 21                                          Manchester     19570   14195
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    29840   30745   32075   35740   44565   77630   80450   64130
# ...

# %%
sns.barplot(x ='May-14', y ='local authority: county / unitary (as of April 2021)', data = May14_largest )
plt.title('Top 10 Highest Claimant Counties in 2014', size= 16)
plt.xlabel('Number of Claimants', size = 14)
plt.show()

# %%
May15_largest= df.nlargest(n=10, columns = ['May-15'])
May15_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     47370   37725
# 189                                       Glasgow City     22825   17475
# 133                                               Kent     27030   19795
# 48                                               Leeds     24295   18525
# 29                                          Lancashire     22030   16060
# 31                                           Liverpool     19490   14985
# 81                                               Essex     25300   17255
# 45                                            Bradford     19415   15630
# 208                                            Belfast     15990   14210
# 21                                          Manchester     19570   14195
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    29840   30745   32075   35740   44565   77630   80450   64130
# ...

# %%
sns.barplot(x ='May-15', y ='local authority: county / unitary (as of April 2021)', data = May15_largest )
plt.title('Top 10 Highest Claimant Counties in 2015',size=16)
plt.xlabel('Number of Claimants', size=14)
plt.show()

# %%
May16_largest= df.nlargest(n=10, columns = ['May-16'])
May16_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     47370   37725
# 133                                               Kent     27030   19795
# 189                                       Glasgow City     22825   17475
# 29                                          Lancashire     22030   16060
# 81                                               Essex     25300   17255
# 48                                               Leeds     24295   18525
# 31                                           Liverpool     19490   14985
# 21                                          Manchester     19570   14195
# 44                                           Sheffield     16980   13095
# 208                                            Belfast     15990   14210
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    29840   30745   32075   35740   44565   77630   80450   64130
# ...

# %%
sns.barplot(x ='May-16', y ='local authority: county / unitary (as of April 2021)', data = May16_largest )
plt.title('Top 10 Highest Claimant Counties in 2016', size =16)
plt.xlabel(' Number of Claimants', size = 14)
plt.show()

# %%
May17_largest= df.nlargest(n=10, columns = ['May-17'])
May17_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     47370   37725
# 133                                               Kent     27030   19795
# 29                                          Lancashire     22030   16060
# 189                                       Glasgow City     22825   17475
# 81                                               Essex     25300   17255
# 31                                           Liverpool     19490   14985
# 48                                               Leeds     24295   18525
# 21                                          Manchester     19570   14195
# 44                                           Sheffield     16980   13095
# 45                                            Bradford     19415   15630
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    29840   30745   32075   35740   44565   77630   80450   64130
# ...

# %%
sns.barplot(x ='May-17', y ='local authority: county / unitary (as of April 2021)', data = May17_largest )
plt.title('Top 10 Highest Claimant Counties in 2017', size =16)
plt.xlabel('Number of Claimants', size=14)
plt.show()

# %%
May18_largest= df.nlargest(n=10, columns = ['May-18'])
May18_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     47370   37725
# 133                                               Kent     27030   19795
# 29                                          Lancashire     22030   16060
# 189                                       Glasgow City     22825   17475
# 81                                               Essex     25300   17255
# 21                                          Manchester     19570   14195
# 31                                           Liverpool     19490   14985
# 48                                               Leeds     24295   18525
# 1                                        County Durham     14825   10275
# 104                                            Croydon      9475    6620
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    29840   30745   32075   35740   44565   77630   80450   64130
# ...

# %%
sns.barplot(x ='May-18', y ='local authority: county / unitary (as of April 2021)', data = May18_largest )
plt.title('Top 10 Highest Claimant Counties in 2018', size =16)
plt.xlabel('Number of Claimants', size=14)
plt.show()

# %%
May19_largest= df.nlargest(n=10, columns = ['May-19'])
May19_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     47370   37725
# 133                                               Kent     27030   19795
# 29                                          Lancashire     22030   16060
# 81                                               Essex     25300   17255
# 189                                       Glasgow City     22825   17475
# 21                                          Manchester     19570   14195
# 48                                               Leeds     24295   18525
# 45                                            Bradford     19415   15630
# 31                                           Liverpool     19490   14985
# 1                                        County Durham     14825   10275
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    29840   30745   32075   35740   44565   77630   80450   64130
# ...

# %%
sns.barplot(x ='May-19', y ='local authority: county / unitary (as of April 2021)', data = May19_largest )
plt.title('Top 10 Highest Claimant Counties in 2019', size =16)
plt.xlabel('Number of Claimants ', size =14)
plt.show()

# %%
May20_largest= df.nlargest(n=10, columns = ['May-20'])
May20_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     47370   37725
# 133                                               Kent     27030   19795
# 81                                               Essex     25300   17255
# 29                                          Lancashire     22030   16060
# 82                                       Hertfordshire     16865   12045
# 132                                          Hampshire     14865    9185
# 189                                       Glasgow City     22825   17475
# 48                                               Leeds     24295   18525
# 21                                          Manchester     19570   14195
# 45                                            Bradford     19415   15630
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    29840   30745   32075   35740   44565   77630   80450   64130
# ...

# %%
sns.barplot(x ='May-20', y ='local authority: county / unitary (as of April 2021)', data = May20_largest )
plt.xlabel('Number of Claimants', size=14)
plt.title('Top 10 Highest Claimant Counties in 2020', size =16)
plt.show()

# %%
May21_largest= df.nlargest(n=10, columns = ['May-21'])
May21_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     47370   37725
# 133                                               Kent     27030   19795
# 81                                               Essex     25300   17255
# 29                                          Lancashire     22030   16060
# 82                                       Hertfordshire     16865   12045
# 189                                       Glasgow City     22825   17475
# 48                                               Leeds     24295   18525
# 21                                          Manchester     19570   14195
# 132                                          Hampshire     14865    9185
# 45                                            Bradford     19415   15630
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    29840   30745   32075   35740   44565   77630   80450   64130
# ...

# %%
sns.barplot(x ='May-21', y ='local authority: county / unitary (as of April 2021)', data = May21_largest )
plt.xlabel('Number of Claimants', size=14)
plt.title('10 Highest Claimant Counties in 2021', size =16)
plt.show()

# %%
May22_largest= df.nlargest(n=10, columns = ['May-22'])
May22_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     47370   37725
# 133                                               Kent     27030   19795
# 29                                          Lancashire     22030   16060
# 81                                               Essex     25300   17255
# 21                                          Manchester     19570   14195
# 45                                            Bradford     19415   15630
# 48                                               Leeds     24295   18525
# 189                                       Glasgow City     22825   17475
# 82                                       Hertfordshire     16865   12045
# 31                                           Liverpool     19490   14985
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    29840   30745   32075   35740   44565   77630   80450   64130
# ...

# %%
sns.barplot(x ='May-22', y ='local authority: county / unitary (as of April 2021)', data = May22_largest )
plt.title('Top 10 Highest Claimant Counties in 2022', size =16)
plt.xlabel('Number of Claimants', size = 14)
plt.show()

# %%
# use melt function to sort the year cloumns (identifier columns) as May and measured columns as vals to make it easier to plot the graph
df13_largest = May13_largest.melt('local authority: county / unitary (as of April 2021)', var_name='May', value_name='Vals')
df13_largest
# Out:
#    local authority: county / unitary (as of April 2021)     May   Vals
# 0                                          Birmingham    May-13  47370
# 1                                                Kent    May-13  27030
# 2                                               Essex    May-13  25300
# 3                                               Leeds    May-13  24295
# 4                                        Glasgow City    May-13  22825
# ..                                                ...       ...    ...
# 95                                         Lancashire    May-22  27085
# 96                                         Manchester    May-22  24060
# 97                                          Liverpool    May-22  19705
# 98                                           Bradford    May-22  23630
# 99                                            Norfolk    May-22  15905
#
# [100 rows x 3 columns]

# %%
#Use melt function to plot the each year graph based on top 10 highest value in May 2013. 
graph_May13_10largest = sns.catplot(y= 'local authority: county / unitary (as of April 2021)', x= 'Vals', hue ='May', data= df13_largest, kind ='point')
#you can see clearly that the claimants count has dramatically increased from 2020 t0 2021 and still high on 2022. There are 
# areas that hit high during the covid 19 and has increased the claimants count.

# %%
df15_largest= May15_largest.melt('local authority: county / unitary (as of April 2021)', var_name='May', value_name ='Vals')
df15_largest
# Out:
#    local authority: county / unitary (as of April 2021)     May   Vals
# 0                                          Birmingham    May-13  47370
# 1                                        Glasgow City    May-13  22825
# 2                                                Kent    May-13  27030
# 3                                               Leeds    May-13  24295
# 4                                          Lancashire    May-13  22030
# ..                                                ...       ...    ...
# 95                                          Liverpool    May-22  19705
# 96                                              Essex    May-22  26840
# 97                                           Bradford    May-22  23630
# 98                                            Belfast    May-22   9415
# 99                                         Manchester    May-22  24060
#
# [100 rows x 3 columns]

# %%
graph_May15_10largest = sns.catplot(y = 'local authority: county / unitary (as of April 2021)', x= 'Vals', hue ='May', data = df15_largest, kind = 'point')

# %%
df21_largest = May21_largest.melt('local authority: county / unitary (as of April 2021)', var_name ='May', value_name='Vals')
df21_largest
# Out:
#    local authority: county / unitary (as of April 2021)     May   Vals
# 0                                          Birmingham    May-13  47370
# 1                                                Kent    May-13  27030
# 2                                               Essex    May-13  25300
# 3                                          Lancashire    May-13  22030
# 4                                       Hertfordshire    May-13  16865
# ..                                                ...       ...    ...
# 95                                       Glasgow City    May-22  22660
# 96                                              Leeds    May-22  23510
# 97                                         Manchester    May-22  24060
# 98                                          Hampshire    May-22  19365
# 99                                           Bradford    May-22  23630
#
# [100 rows x 3 columns]

# %%
graph_May21_20largest = sns.catplot(y = 'local authority: county / unitary (as of April 2021)', x= 'Vals', hue='May', data =df21_largest, kind='point')

# %%
# Now we look into the Claimants Age 16+ as proportion of residents aged 16-64.

# %%
# Claimants as a proportion of residents aged 16-64
#use na_values function to clean the data with blank data (#,!)
data_prop_age = pd.read_csv('claimants count_local authority_nomis.csv', skiprows=266, nrows=217, na_values=('#','!'))
data_prop_age
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 0                                           Darlington       5.3     4.0
# 1                                        County Durham       4.5     3.1
# 2                                           Hartlepool       7.6     5.6
# 3                                        Middlesbrough       8.1     6.0
# 4                                       Northumberland       4.1     3.1
# ..                                                 ...       ...     ...
# 212                            Lisburn and Castlereagh       3.3     2.7
# 213                                Mid and East Antrim       4.6     3.7
# 214                                         Mid Ulster       4.2     3.5
# 215                             Newry, Mourne and Down       5.6     4.7
# 216                                Ards and North Down       4.1     3.7
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# ...

# %%
# load the data into dataframe
df_prop_age = pd.DataFrame(data_prop_age)
df_prop_age
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 0                                           Darlington       5.3     4.0
# 1                                        County Durham       4.5     3.1
# 2                                           Hartlepool       7.6     5.6
# 3                                        Middlesbrough       8.1     6.0
# 4                                       Northumberland       4.1     3.1
# ..                                                 ...       ...     ...
# 212                            Lisburn and Castlereagh       3.3     2.7
# 213                                Mid and East Antrim       4.6     3.7
# 214                                         Mid Ulster       4.2     3.5
# 215                             Newry, Mourne and Down       5.6     4.7
# 216                                Ards and North Down       4.1     3.7
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# ...

# %%
p = sns.histplot(data= May13_largest, y='local authority: county / unitary (as of April 2021)', hue = 'May-13' )

# %%
# Claimants aged 16+ as proportion of aged 16-64
May13_largest = df_prop_age.nlargest(n =10, columns = ['May-13'])
May13_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 36                         Kingston upon Hull, City of       8.4     6.3
# 3                                        Middlesbrough       8.1     6.0
# 210                            Derry City and Strabane       8.1     7.9
# 72                                       Wolverhampton       7.8     6.2
# 2                                           Hartlepool       7.6     5.6
# 170                                      Blaenau Gwent       7.4     5.4
# 10                                      South Tyneside       7.3     5.4
# 208                                            Belfast       7.2     6.4
# 69                                            Sandwell       6.9     5.0
# 66                                          Birmingham       6.8     5.3
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 36      4.5     3.9     3.7     3.8     4.9     9.8     9.1     6.5
# ...

# %%
sns.barplot(x ='May-13', y ='local authority: county / unitary (as of April 2021)', data = May13_largest )
plt.xlabel('Claimants percentage as proportion of residents Aged 16-64', size =13)
plt.title('Highest Claimant Counties as proportion of residents Aged 16-64 in 2013', size= 14)
plt.show()

# %%
May14_largest = df_prop_age.nlargest(n =10, columns = ['May-14'])
May14_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 210                            Derry City and Strabane       8.1     7.9
# 208                                            Belfast       7.2     6.4
# 36                         Kingston upon Hull, City of       8.4     6.3
# 72                                       Wolverhampton       7.8     6.2
# 3                                        Middlesbrough       8.1     6.0
# 2                                           Hartlepool       7.6     5.6
# 10                                      South Tyneside       7.3     5.4
# 170                                      Blaenau Gwent       7.4     5.4
# 66                                          Birmingham       6.8     5.3
# 194                                     North Ayrshire       6.2     5.1
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 210     7.1     5.9     5.1     4.6     4.7     7.5     6.4     4.8
# ...

# %%
sns.barplot(x ='May-14', y ='local authority: county / unitary (as of April 2021)', data = May14_largest )
plt.xlabel('Claimants percentage as proportion of residents Aged 16-64', size=13)
plt.title('Highest Claimant Counties as proportion of residents Aged 16-64 in 2014', size= 14)
plt.show()

# %%
May15_largest = df_prop_age.nlargest(n =10, columns = ['May-15'])
May15_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 210                            Derry City and Strabane       8.1     7.9
# 208                                            Belfast       7.2     6.4
# 36                         Kingston upon Hull, City of       8.4     6.3
# 10                                      South Tyneside       7.3     5.4
# 66                                          Birmingham       6.8     5.3
# 72                                       Wolverhampton       7.8     6.2
# 3                                        Middlesbrough       8.1     6.0
# 170                                      Blaenau Gwent       7.4     5.4
# 13                                           Blackpool       6.2     4.8
# 2                                           Hartlepool       7.6     5.6
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 210     7.1     5.9     5.1     4.6     4.7     7.5     6.4     4.8
# ...

# %%
sns.barplot(x ='May-15', y ='local authority: county / unitary (as of April 2021)', data = May15_largest )
plt.xlabel('Claimants percentage as proportion of residents Aged 16-64',size =13)
plt.title('Highest Claimant Counties as proportion of residents Aged 16-64 in 2015', size= 14)
plt.show()

# %%
May16_largest = df_prop_age.nlargest(n =10, columns = ['May-16'])
May16_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 210                            Derry City and Strabane       8.1     7.9
# 2                                           Hartlepool       7.6     5.6
# 3                                        Middlesbrough       8.1     6.0
# 10                                      South Tyneside       7.3     5.4
# 66                                          Birmingham       6.8     5.3
# 72                                       Wolverhampton       7.8     6.2
# 194                                     North Ayrshire       6.2     5.1
# 208                                            Belfast       7.2     6.4
# 170                                      Blaenau Gwent       7.4     5.4
# 36                         Kingston upon Hull, City of       8.4     6.3
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 210     7.1     5.9     5.1     4.6     4.7     7.5     6.4     4.8
# ...

# %%
sns.barplot(x ='May-16', y ='local authority: county / unitary (as of April 2021)', data = May16_largest )
plt.xlabel('Claimants percentage as proportion of residents Aged 16-64',size=13)
plt.title('Highest Claimant Counties as proportion of residents Aged 16-64 in 2016', size= 14)
plt.show()

# %%
May17_largest = df_prop_age.nlargest(n =10, columns = ['May-17'])
May17_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 2                                           Hartlepool       7.6     5.6
# 210                            Derry City and Strabane       8.1     7.9
# 3                                        Middlesbrough       8.1     6.0
# 10                                      South Tyneside       7.3     5.4
# 191                                         Inverclyde       5.3     3.7
# 13                                           Blackpool       6.2     4.8
# 66                                          Birmingham       6.8     5.3
# 72                                       Wolverhampton       7.8     6.2
# 194                                     North Ayrshire       6.2     5.1
# 5                                 Redcar and Cleveland       6.6     4.8
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 2       3.9     4.9     5.7     7.0     6.5     9.4     7.9     5.3
# ...

# %%
sns.barplot(x ='May-17', y ='local authority: county / unitary (as of April 2021)', data = May17_largest )
plt.xlabel('Claimants percentage as proportion of residents Aged 16-64',size=13)
plt.title('Highest Claimant Counties as proportion of residents Aged 16-64 in 2017', size= 14)
plt.show()

# %%
May18_largest = df_prop_age.nlargest(n =10, columns = ['May-18'])
May18_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 2                                           Hartlepool       7.6     5.6
# 191                                         Inverclyde       5.3     3.7
# 66                                          Birmingham       6.8     5.3
# 194                                     North Ayrshire       6.2     5.1
# 72                                       Wolverhampton       7.8     6.2
# 10                                      South Tyneside       7.3     5.4
# 210                            Derry City and Strabane       8.1     7.9
# 3                                        Middlesbrough       8.1     6.0
# 13                                           Blackpool       6.2     4.8
# 181                                      East Ayrshire       5.8     4.5
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 2       3.9     4.9     5.7     7.0     6.5     9.4     7.9     5.3
# ...

# %%
sns.barplot(x ='May-18', y ='local authority: county / unitary (as of April 2021)', data = May18_largest )
plt.xlabel('Claimants percentage as proportion of residents Aged 16-64', size=13)
plt.title('Highest Claimant Counties as proportion of residents Aged 16-64 in 2018', size= 14)
plt.show()

# %%
May19_largest = df_prop_age.nlargest(n =10, columns = ['May-19'])
May19_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 2                                           Hartlepool       7.6     5.6
# 66                                          Birmingham       6.8     5.3
# 10                                      South Tyneside       7.3     5.4
# 13                                           Blackpool       6.2     4.8
# 3                                        Middlesbrough       8.1     6.0
# 72                                       Wolverhampton       7.8     6.2
# 194                                     North Ayrshire       6.2     5.1
# 191                                         Inverclyde       5.3     3.7
# 36                         Kingston upon Hull, City of       8.4     6.3
# 11                                          Sunderland       5.5     4.1
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 2       3.9     4.9     5.7     7.0     6.5     9.4     7.9     5.3
# ...

# %%
sns.barplot(x ='May-19', y ='local authority: county / unitary (as of April 2021)', data = May19_largest )
plt.xlabel('Claimants percentage as proportion of residents Aged 16-64', size=13)
plt.title('Highest Claimant Counties as proportion of residents Aged 16-64 in 2019', size= 14)
plt.show()

# %%
May20_largest = df_prop_age.nlargest(n =10, columns = ['May-20'])
May20_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 13                                           Blackpool       6.2     4.8
# 66                                          Birmingham       6.8     5.3
# 72                                       Wolverhampton       7.8     6.2
# 89                                            Haringey       5.1     3.9
# 3                                        Middlesbrough       8.1     6.0
# 99                                Barking and Dagenham       5.6     3.8
# 36                         Kingston upon Hull, City of       8.4     6.3
# 10                                      South Tyneside       7.3     5.4
# 102                                              Brent       4.4     3.3
# 2                                           Hartlepool       7.6     5.6
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 13      4.0     3.8     4.4     4.5     5.7    12.4    11.3     7.5
# ...

# %%
sns.barplot(x ='May-20', y ='local authority: county / unitary (as of April 2021)', data = May20_largest )
plt.xlabel('Claimants percentage as proportion of residents Aged 16-64', size=13)
plt.title('Highest Claimant Counties as proportion of residents Aged 16-64 in 2020', size= 14)
plt.show()

# %%
May21_largest = df_prop_age.nlargest(n =10, columns = ['May-21'])
May21_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 13                                           Blackpool       6.2     4.8
# 89                                            Haringey       5.1     3.9
# 66                                          Birmingham       6.8     5.3
# 94                                              Newham       4.8     3.3
# 102                                              Brent       4.4     3.3
# 99                                Barking and Dagenham       5.6     3.8
# 72                                       Wolverhampton       7.8     6.2
# 117                                     Waltham Forest       5.1     3.6
# 3                                        Middlesbrough       8.1     6.0
# 105                                             Ealing       3.7     2.9
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 13      4.0     3.8     4.4     4.5     5.7    12.4    11.3     7.5
# ...

# %%
sns.barplot(x ='May-21', y ='local authority: county / unitary (as of April 2021)', data = May21_largest )
plt.xlabel('Claimants percentage as proportion of residents Aged 16-64', size=13)
plt.title('Highest Claimant Counties as proportion of residents Aged 16-64 in 2021', size= 14)
plt.show()

# %%
May22_largest = df_prop_age.nlargest(n =10, columns = ['May-22'])
May22_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham       6.8     5.3
# 72                                       Wolverhampton       7.8     6.2
# 13                                           Blackpool       6.2     4.8
# 89                                            Haringey       5.1     3.9
# 45                                            Bradford       5.9     4.8
# 22                                              Oldham       5.6     3.9
# 99                                Barking and Dagenham       5.6     3.8
# 102                                              Brent       4.4     3.3
# 69                                            Sandwell       6.9     5.0
# 94                                              Newham       4.8     3.3
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66      4.2     4.2     4.4     4.9     6.1    10.6    11.0     8.7
# ...

# %%
sns.barplot(x ='May-22', y ='local authority: county / unitary (as of April 2021)', data = May22_largest )
plt.xlabel('Claimants percentage as proportion of residents Aged 16-64', size=13)
plt.title('Highest Claimant Counties as proportion of residents Aged 16-64 in 2022', size= 14)
plt.show()

# %%
df13_largest = May13_largest.melt('local authority: county / unitary (as of April 2021)', var_name='May', value_name='percentage')
df13_largest
# Out:
#    local authority: county / unitary (as of April 2021)     May  percentage
# 0                         Kingston upon Hull, City of    May-13         8.4
# 1                                       Middlesbrough    May-13         8.1
# 2                             Derry City and Strabane    May-13         8.1
# 3                                       Wolverhampton    May-13         7.8
# 4                                          Hartlepool    May-13         7.6
# ..                                                ...       ...         ...
# 95                                      Blaenau Gwent    May-22         4.3
# 96                                     South Tyneside    May-22         5.8
# 97                                            Belfast    May-22         4.2
# 98                                           Sandwell    May-22         6.8
# 99                                         Birmingham    May-22         8.7
#
# [100 rows x 3 columns]

# %%
# Declare the percentage column as float value to plot the graph 
df13_largest['percentage']= df13_largest['percentage'].astype('float')
graph_largest_May13 = sns.catplot(y= 'local authority: county / unitary (as of April 2021)', x= 'percentage', hue ='May', data= df13_largest, kind ='point')

# %%
May15_largest = df_prop_age.nlargest(n = 10, columns =['May-15'])
May15_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 210                            Derry City and Strabane       8.1     7.9
# 208                                            Belfast       7.2     6.4
# 36                         Kingston upon Hull, City of       8.4     6.3
# 10                                      South Tyneside       7.3     5.4
# 66                                          Birmingham       6.8     5.3
# 72                                       Wolverhampton       7.8     6.2
# 3                                        Middlesbrough       8.1     6.0
# 170                                      Blaenau Gwent       7.4     5.4
# 13                                           Blackpool       6.2     4.8
# 2                                           Hartlepool       7.6     5.6
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 210     7.1     5.9     5.1     4.6     4.7     7.5     6.4     4.8
# ...

# %%
df15_largest = May15_largest.melt('local authority: county / unitary (as of April 2021)', var_name='May', value_name='percentage')
df15_largest
#a.plot.scatter(x = 'May-14', y = 'local authority: county / unitary (as of April 2021)')
# Out:
#    local authority: county / unitary (as of April 2021)     May  percentage
# 0                             Derry City and Strabane    May-13         8.1
# 1                                             Belfast    May-13         7.2
# 2                         Kingston upon Hull, City of    May-13         8.4
# 3                                      South Tyneside    May-13         7.3
# 4                                          Birmingham    May-13         6.8
# ..                                                ...       ...         ...
# 95                                      Wolverhampton    May-22         7.6
# 96                                      Middlesbrough    May-22         6.2
# 97                                      Blaenau Gwent    May-22         4.3
# 98                                          Blackpool    May-22         7.5
# 99                                         Hartlepool    May-22         5.3
#
# [100 rows x 3 columns]

# %%
# Declare the percentage column as float value to plot the graph 
df15_largest['percentage']= df15_largest['percentage'].astype('float')
graph_largest_May15 = sns.catplot(y= 'local authority: county / unitary (as of April 2021)', x= 'percentage', hue ='May', data= df15_largest, kind ='point')

# %%
May18_largest = df_prop_age.nlargest(n = 10, columns =['May-18'])
May18_largest
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 2                                           Hartlepool       7.6     5.6
# 191                                         Inverclyde       5.3     3.7
# 66                                          Birmingham       6.8     5.3
# 194                                     North Ayrshire       6.2     5.1
# 72                                       Wolverhampton       7.8     6.2
# 10                                      South Tyneside       7.3     5.4
# 210                            Derry City and Strabane       8.1     7.9
# 3                                        Middlesbrough       8.1     6.0
# 13                                           Blackpool       6.2     4.8
# 181                                      East Ayrshire       5.8     4.5
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 2       3.9     4.9     5.7     7.0     6.5     9.4     7.9     5.3
# ...

# %%
df18_largest = May18_largest.melt('local authority: county / unitary (as of April 2021)', var_name='May', value_name='percentage')
df18_largest
# Out:
#    local authority: county / unitary (as of April 2021)     May  percentage
# 0                                          Hartlepool    May-13         7.6
# 1                                          Inverclyde    May-13         5.3
# 2                                          Birmingham    May-13         6.8
# 3                                      North Ayrshire    May-13         6.2
# 4                                       Wolverhampton    May-13         7.8
# ..                                                ...       ...         ...
# 95                                     South Tyneside    May-22         5.8
# 96                            Derry City and Strabane    May-22         4.8
# 97                                      Middlesbrough    May-22         6.2
# 98                                          Blackpool    May-22         7.5
# 99                                      East Ayrshire    May-22         4.5
#
# [100 rows x 3 columns]

# %%
# Declare the percentage column as float value to plot the graph 
df18_largest['percentage']= df18_largest['percentage'].astype('float')
graph_largest_May18 = sns.catplot(y= 'local authority: county / unitary (as of April 2021)', x= 'percentage', hue ='May', data= df18_largest, kind ='point')

# %%
#Claimants count of aged 16-24 years
data_aged16_24 = pd.read_csv('claimants count_local authority_nomis.csv', skiprows=527, nrows=217, na_values =('#','!'))
data_aged16_24
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 0                                           Darlington       995     620
# 1                                        County Durham      4635    2965
# 2                                           Hartlepool      1265     805
# 3                                        Middlesbrough      2065    1290
# 4                                       Northumberland      2320    1595
# ..                                                 ...       ...     ...
# 212                            Lisburn and Castlereagh       785     600
# 213                                Mid and East Antrim      1100     795
# 214                                         Mid Ulster       890     720
# 215                             Newry, Mourne and Down      1535    1140
# 216                                Ards and North Down      1090     925
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# ...

# %%
#use dataframe to process the data 
df_16_24= pd.DataFrame(data_aged16_24)
df_16_24
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 0                                           Darlington       995     620
# 1                                        County Durham      4635    2965
# 2                                           Hartlepool      1265     805
# 3                                        Middlesbrough      2065    1290
# 4                                       Northumberland      2320    1595
# ..                                                 ...       ...     ...
# 212                            Lisburn and Castlereagh       785     600
# 213                                Mid and East Antrim      1100     795
# 214                                         Mid Ulster       890     720
# 215                             Newry, Mourne and Down      1535    1140
# 216                                Ards and North Down      1090     925
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# ...

# %%
#Check the distribution of the claimant counts of aged 16-24 years through histogram 
df_16_24.hist(bins = 50, figsize =(15,15))
plt.show()

# %%
df_16_24.mean(numeric_only=True)
# Out:
# May-13    1796.221198
# May-14    1210.069124
# May-15     832.050691
# May-16     773.041475
# May-17     766.175115
# May-18     797.834101
# May-19     971.866359
# May-20    2323.387097
# May-21    2130.138249
# May-22    1161.474654
# dtype: float64

# %%
largest_May13 = df_16_24.nlargest(n=10, columns =['May-13'])
largest_May13
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     11945    8505
# 133                                               Kent      7370    5065
# 81                                               Essex      6960    4355
# 48                                               Leeds      6510    4655
# 29                                          Lancashire      6200    4160
# 189                                       Glasgow City      5525    4010
# 45                                            Bradford      5405    3780
# 31                                           Liverpool      5150    3670
# 83                                             Norfolk      5005    3000
# 44                                           Sheffield      4860    3430
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     6160    6525    6365    6690    8105   15315   15550   10665
# ...

# %%
sns.barplot(x ='May-13', y ='local authority: county / unitary (as of April 2021)', data = largest_May13 )
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants of Aged 16-24 in 2013', size =15)
plt.show()

# %%
largest_May14 = df_16_24.nlargest(n=10, columns =['May-14'])
largest_May14
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     11945    8505
# 133                                               Kent      7370    5065
# 48                                               Leeds      6510    4655
# 81                                               Essex      6960    4355
# 29                                          Lancashire      6200    4160
# 189                                       Glasgow City      5525    4010
# 45                                            Bradford      5405    3780
# 31                                           Liverpool      5150    3670
# 44                                           Sheffield      4860    3430
# 208                                            Belfast      4175    3420
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     6160    6525    6365    6690    8105   15315   15550   10665
# ...

# %%
sns.barplot(x ='May-14', y ='local authority: county / unitary (as of April 2021)', data = largest_May14 )
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants of Aged 16-24 in 2014', size =15)
plt.show()

# %%
largest_May15 = df_16_24.nlargest(n=10, columns =['May-15'])
largest_May15
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     11945    8505
# 133                                               Kent      7370    5065
# 29                                          Lancashire      6200    4160
# 48                                               Leeds      6510    4655
# 189                                       Glasgow City      5525    4010
# 31                                           Liverpool      5150    3670
# 81                                               Essex      6960    4355
# 208                                            Belfast      4175    3420
# 45                                            Bradford      5405    3780
# 21                                          Manchester      4760    3230
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     6160    6525    6365    6690    8105   15315   15550   10665
# ...

# %%
sns.barplot(x ='May-15', y ='local authority: county / unitary (as of April 2021)', data = largest_May15 )
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants of Aged 16-24 in 2015', size =15)
plt.show()

# %%
largest_May16 = df_16_24.nlargest(n=10, columns =['May-16'])
largest_May16
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     11945    8505
# 133                                               Kent      7370    5065
# 29                                          Lancashire      6200    4160
# 189                                       Glasgow City      5525    4010
# 81                                               Essex      6960    4355
# 48                                               Leeds      6510    4655
# 31                                           Liverpool      5150    3670
# 21                                          Manchester      4760    3230
# 208                                            Belfast      4175    3420
# 44                                           Sheffield      4860    3430
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     6160    6525    6365    6690    8105   15315   15550   10665
# ...

# %%
sns.barplot(x ='May-16', y ='local authority: county / unitary (as of April 2021)', data = largest_May16)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants of Aged 16-24 in 2016', size =15)
plt.show()

# %%
largest_May17 = df_16_24.nlargest(n=10, columns =['May-17'])
largest_May17
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     11945    8505
# 133                                               Kent      7370    5065
# 29                                          Lancashire      6200    4160
# 189                                       Glasgow City      5525    4010
# 81                                               Essex      6960    4355
# 48                                               Leeds      6510    4655
# 31                                           Liverpool      5150    3670
# 44                                           Sheffield      4860    3430
# 1                                        County Durham      4635    2965
# 45                                            Bradford      5405    3780
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     6160    6525    6365    6690    8105   15315   15550   10665
# ...

# %%
sns.barplot(x ='May-17', y ='local authority: county / unitary (as of April 2021)', data = largest_May17)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants of Aged 16-24 in 2017', size =15)
plt.show()

# %%
largest_May18 = df_16_24.nlargest(n=10, columns =['May-18'])
largest_May18
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     11945    8505
# 133                                               Kent      7370    5065
# 29                                          Lancashire      6200    4160
# 81                                               Essex      6960    4355
# 189                                       Glasgow City      5525    4010
# 1                                        County Durham      4635    2965
# 48                                               Leeds      6510    4655
# 21                                          Manchester      4760    3230
# 45                                            Bradford      5405    3780
# 31                                           Liverpool      5150    3670
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     6160    6525    6365    6690    8105   15315   15550   10665
# ...

# %%
sns.barplot(x ='May-18', y ='local authority: county / unitary (as of April 2021)', data = largest_May18 )
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants of Aged 16-24 in 2018', size =15)
plt.show()

# %%
largest_May19 = df_16_24.nlargest(n=10, columns =['May-19'])
largest_May19
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     11945    8505
# 133                                               Kent      7370    5065
# 29                                          Lancashire      6200    4160
# 81                                               Essex      6960    4355
# 21                                          Manchester      4760    3230
# 1                                        County Durham      4635    2965
# 45                                            Bradford      5405    3780
# 189                                       Glasgow City      5525    4010
# 48                                               Leeds      6510    4655
# 56                                        Lincolnshire      4190    2920
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     6160    6525    6365    6690    8105   15315   15550   10665
# ...

# %%
sns.barplot(x ='May-19', y ='local authority: county / unitary (as of April 2021)', data = largest_May19 )
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants of Aged 16-24 in 2019', size =15)
plt.show()

# %%
largest_May20 = df_16_24.nlargest(n=10, columns =['May-20'])
largest_May20
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     11945    8505
# 133                                               Kent      7370    5065
# 81                                               Essex      6960    4355
# 29                                          Lancashire      6200    4160
# 132                                          Hampshire      3975    2155
# 48                                               Leeds      6510    4655
# 82                                       Hertfordshire      3740    2480
# 21                                          Manchester      4760    3230
# 45                                            Bradford      5405    3780
# 189                                       Glasgow City      5525    4010
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     6160    6525    6365    6690    8105   15315   15550   10665
# ...

# %%
sns.barplot(x ='May-20', y ='local authority: county / unitary (as of April 2021)', data = largest_May20)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants of Aged 16-24 in 2020', size =15)
plt.show()

# %%
largest_May21 = df_16_24.nlargest(n=10, columns =['May-21'])
largest_May21
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     11945    8505
# 133                                               Kent      7370    5065
# 81                                               Essex      6960    4355
# 29                                          Lancashire      6200    4160
# 48                                               Leeds      6510    4655
# 45                                            Bradford      5405    3780
# 21                                          Manchester      4760    3230
# 82                                       Hertfordshire      3740    2480
# 132                                          Hampshire      3975    2155
# 189                                       Glasgow City      5525    4010
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     6160    6525    6365    6690    8105   15315   15550   10665
# ...

# %%
sns.barplot(x ='May-21', y ='local authority: county / unitary (as of April 2021)', data = largest_May21 )
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants of Aged 16-24 in 2021', size =15)
plt.show()

# %%
largest_May22 = df_16_24.nlargest(n=10, columns =['May-22'])
largest_May22
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     11945    8505
# 133                                               Kent      7370    5065
# 29                                          Lancashire      6200    4160
# 45                                            Bradford      5405    3780
# 81                                               Essex      6960    4355
# 48                                               Leeds      6510    4655
# 21                                          Manchester      4760    3230
# 189                                       Glasgow City      5525    4010
# 31                                           Liverpool      5150    3670
# 132                                          Hampshire      3975    2155
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     6160    6525    6365    6690    8105   15315   15550   10665
# ...

# %%
sns.barplot(x ='May-22', y ='local authority: county / unitary (as of April 2021)', data = largest_May22)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants of Aged 16-24 in 2022', size =15)
plt.show()

# %%
df_largest_May13 = largest_May13.melt('local authority: county / unitary (as of April 2021)', var_name='May', value_name='vals')
df_largest_May13
# Out:
#    local authority: county / unitary (as of April 2021)     May   vals
# 0                                          Birmingham    May-13  11945
# 1                                                Kent    May-13   7370
# 2                                               Essex    May-13   6960
# 3                                               Leeds    May-13   6510
# 4                                          Lancashire    May-13   6200
# ..                                                ...       ...    ...
# 95                                       Glasgow City    May-22   3250
# 96                                           Bradford    May-22   4220
# 97                                          Liverpool    May-22   3195
# 98                                            Norfolk    May-22   2775
# 99                                          Sheffield    May-22   2795
#
# [100 rows x 3 columns]

# %%
graph_largest_May13 = sns.catplot(y= 'local authority: county / unitary (as of April 2021)', x= 'vals', hue ='May', data= df_largest_May13, kind ='point')

# %%
df_largest_May15 = largest_May15.melt('local authority: county / unitary (as of April 2021)', var_name='May', value_name='vals')
df_largest_May15
# Out:
#    local authority: county / unitary (as of April 2021)     May   vals
# 0                                          Birmingham    May-13  11945
# 1                                                Kent    May-13   7370
# 2                                          Lancashire    May-13   6200
# 3                                               Leeds    May-13   6510
# 4                                        Glasgow City    May-13   5525
# ..                                                ...       ...    ...
# 95                                          Liverpool    May-22   3195
# 96                                              Essex    May-22   4150
# 97                                            Belfast    May-22   1540
# 98                                           Bradford    May-22   4220
# 99                                         Manchester    May-22   4090
#
# [100 rows x 3 columns]

# %%
graph_largest_May15 = sns.catplot(y= 'local authority: county / unitary (as of April 2021)', x= 'vals', hue ='May', data= df_largest_May15,kind ='point')

# %%
df_largest_May17 = largest_May17.melt('local authority: county / unitary (as of April 2021)', var_name='May', value_name='vals')
df_largest_May17
# Out:
#    local authority: county / unitary (as of April 2021)     May   vals
# 0                                          Birmingham    May-13  11945
# 1                                                Kent    May-13   7370
# 2                                          Lancashire    May-13   6200
# 3                                        Glasgow City    May-13   5525
# 4                                               Essex    May-13   6960
# ..                                                ...       ...    ...
# 95                                              Leeds    May-22   4140
# 96                                          Liverpool    May-22   3195
# 97                                          Sheffield    May-22   2795
# 98                                      County Durham    May-22   2215
# 99                                           Bradford    May-22   4220
#
# [100 rows x 3 columns]

# %%
graph_largest_May17 = sns.catplot(y= 'local authority: county / unitary (as of April 2021)', x= 'vals', hue ='May', data= df_largest_May17,kind ='point')

# %%
df_largest_May19 = largest_May19.melt('local authority: county / unitary (as of April 2021)', var_name='May', value_name='vals')
df_largest_May19
# Out:
#    local authority: county / unitary (as of April 2021)     May   vals
# 0                                          Birmingham    May-13  11945
# 1                                                Kent    May-13   7370
# 2                                          Lancashire    May-13   6200
# 3                                               Essex    May-13   6960
# 4                                          Manchester    May-13   4760
# ..                                                ...       ...    ...
# 95                                      County Durham    May-22   2215
# 96                                           Bradford    May-22   4220
# 97                                       Glasgow City    May-22   3250
# 98                                              Leeds    May-22   4140
# 99                                       Lincolnshire    May-22   2255
#
# [100 rows x 3 columns]

# %%
graph_largest_May19 = sns.catplot(y= 'local authority: county / unitary (as of April 2021)', x= 'vals', hue ='May', data= df_largest_May19,kind ='point')

# %%
#claimant counts of aged 25-49 years
data_aged25_49= pd.read_csv('claimants count_local authority_nomis.csv', skiprows=785, nrows=217, na_values=('#','!'))
data_aged25_49
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 0                                           Darlington      1920    1495
# 1                                        County Durham      7840    5470
# 2                                           Hartlepool      2465    1880
# 3                                        Middlesbrough      4110    3160
# 4                                       Northumberland      4310    3130
# ..                                                 ...       ...     ...
# 212                            Lisburn and Castlereagh      1565    1280
# 213                                Mid and East Antrim      2075    1630
# 214                                         Mid Ulster      2120    1710
# 215                             Newry, Mourne and Down      3435    2825
# 216                                Ards and North Down      2160    1870
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# ...

# %%
# use datafram to process the data
df_25_49=pd.DataFrame(data_aged25_49)
df_25_49
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 0                                           Darlington      1920    1495
# 1                                        County Durham      7840    5470
# 2                                           Hartlepool      2465    1880
# 3                                        Middlesbrough      4110    3160
# 4                                       Northumberland      4310    3130
# ..                                                 ...       ...     ...
# 212                            Lisburn and Castlereagh      1565    1280
# 213                                Mid and East Antrim      2075    1630
# 214                                         Mid Ulster      2120    1710
# 215                             Newry, Mourne and Down      3435    2825
# 216                                Ards and North Down      2160    1870
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# ...

# %%
# Create Histogram to visualise the data distribution
df_25_49.hist(bins = 50, figsize =(15,15))
plt.show()

# %%
# Mean vlaue of claimants of aged 25-49 years
df_25_49.mean(numeric_only=True)
# Out:
# May-13    3900.622120
# May-14    2859.654378
# May-15    2083.479263
# May-16    1969.746544
# May-17    2018.317972
# May-18    2234.078341
# May-19    2823.202765
# May-20    7118.087558
# May-21    6493.801843
# May-22    4410.046083
# dtype: float64

# %%
largest_May13 = df_25_49.nlargest(n=10, columns =['May-13'])
largest_May13
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     27895   22640
# 133                                               Kent     14620   10705
# 48                                               Leeds     14170   10860
# 81                                               Essex     13775    9315
# 189                                       Glasgow City     13580   10335
# 29                                          Lancashire     12195    8915
# 21                                          Manchester     11990    8670
# 31                                           Liverpool     11325    8825
# 45                                            Bradford     11095    9110
# 82                                       Hertfordshire      9690    6820
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    18005   17860   18535   20280   25365   45775   46615   38210
# ...

# %%
sns.barplot(x ='May-13', y ='local authority: county / unitary (as of April 2021)', data = largest_May13)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants of Aged 25-49 in 2013', size =15)
plt.show()

# %%
largest_May14 = df_25_49.nlargest(n=10, columns =['May-14'])
largest_May14
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     27895   22640
# 48                                               Leeds     14170   10860
# 133                                               Kent     14620   10705
# 189                                       Glasgow City     13580   10335
# 81                                               Essex     13775    9315
# 45                                            Bradford     11095    9110
# 29                                          Lancashire     12195    8915
# 31                                           Liverpool     11325    8825
# 21                                          Manchester     11990    8670
# 208                                            Belfast      9180    7995
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    18005   17860   18535   20280   25365   45775   46615   38210
# ...

# %%
sns.barplot(x ='May-14', y ='local authority: county / unitary (as of April 2021)', data = largest_May14)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Authorities with Highest Claimants of Aged 25-49 in 2014', size =15)
plt.show()

# %%
largest_May15 = df_25_49.nlargest(n=10, columns =['May-15'])
largest_May15
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     27895   22640
# 189                                       Glasgow City     13580   10335
# 48                                               Leeds     14170   10860
# 133                                               Kent     14620   10705
# 31                                           Liverpool     11325    8825
# 29                                          Lancashire     12195    8915
# 81                                               Essex     13775    9315
# 21                                          Manchester     11990    8670
# 45                                            Bradford     11095    9110
# 208                                            Belfast      9180    7995
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    18005   17860   18535   20280   25365   45775   46615   38210
# ...

# %%
sns.barplot(x ='May-15', y ='local authority: county / unitary (as of April 2021)', data = largest_May15)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Authorities with Highest Claimants of Aged 25-49 in 2015', size =15)
plt.show()

# %%
largest_May16 = df_25_49.nlargest(n=10, columns =['May-16'])
largest_May16
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     27895   22640
# 189                                       Glasgow City     13580   10335
# 133                                               Kent     14620   10705
# 29                                          Lancashire     12195    8915
# 48                                               Leeds     14170   10860
# 31                                           Liverpool     11325    8825
# 21                                          Manchester     11990    8670
# 81                                               Essex     13775    9315
# 44                                           Sheffield      9595    7465
# 45                                            Bradford     11095    9110
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    18005   17860   18535   20280   25365   45775   46615   38210
# ...

# %%
sns.barplot(x ='May-16', y ='local authority: county / unitary (as of April 2021)', data = largest_May16)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Authorities with Highest Claimants of Aged 25-49 in 2016', size =15)
plt.show()

# %%
largest_May17 = df_25_49.nlargest(n=10, columns =['May-17'])
largest_May17
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     27895   22640
# 29                                          Lancashire     12195    8915
# 189                                       Glasgow City     13580   10335
# 133                                               Kent     14620   10705
# 31                                           Liverpool     11325    8825
# 48                                               Leeds     14170   10860
# 81                                               Essex     13775    9315
# 21                                          Manchester     11990    8670
# 44                                           Sheffield      9595    7465
# 45                                            Bradford     11095    9110
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    18005   17860   18535   20280   25365   45775   46615   38210
# ...

# %%
sns.barplot(x ='May-17', y ='local authority: county / unitary (as of April 2021)', data = largest_May17)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Authorities with Highest Claimants of  Aged 25-49 in 2017', size =15)
plt.show()

# %%
largest_May18 = df_25_49.nlargest(n=10, columns =['May-18'])
largest_May18
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     27895   22640
# 29                                          Lancashire     12195    8915
# 133                                               Kent     14620   10705
# 189                                       Glasgow City     13580   10335
# 21                                          Manchester     11990    8670
# 31                                           Liverpool     11325    8825
# 81                                               Essex     13775    9315
# 48                                               Leeds     14170   10860
# 104                                            Croydon      5680    3850
# 1                                        County Durham      7840    5470
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    18005   17860   18535   20280   25365   45775   46615   38210
# ...

# %%
sns.barplot(x ='May-18', y ='local authority: county / unitary (as of April 2021)', data = largest_May18)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Authorities with Highest Claimants of Aged 25-49 in 2018', size =15)
plt.show()

# %%
largest_May19 = df_25_49.nlargest(n=10, columns =['May-19'])
largest_May19
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     27895   22640
# 133                                               Kent     14620   10705
# 29                                          Lancashire     12195    8915
# 189                                       Glasgow City     13580   10335
# 81                                               Essex     13775    9315
# 21                                          Manchester     11990    8670
# 48                                               Leeds     14170   10860
# 31                                           Liverpool     11325    8825
# 45                                            Bradford     11095    9110
# 1                                        County Durham      7840    5470
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    18005   17860   18535   20280   25365   45775   46615   38210
# ...

# %%
sns.barplot(x ='May-19', y ='local authority: county / unitary (as of April 2021)', data = largest_May19)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Authorities with Highest Claimants of Aged 25-49 in 2019', size =15)
plt.show()

# %%
largest_May20 = df_25_49.nlargest(n=10, columns =['May-20'])
largest_May20
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     27895   22640
# 133                                               Kent     14620   10705
# 81                                               Essex     13775    9315
# 29                                          Lancashire     12195    8915
# 82                                       Hertfordshire      9690    6820
# 189                                       Glasgow City     13580   10335
# 21                                          Manchester     11990    8670
# 48                                               Leeds     14170   10860
# 132                                          Hampshire      7775    4955
# 31                                           Liverpool     11325    8825
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    18005   17860   18535   20280   25365   45775   46615   38210
# ...

# %%
sns.barplot(x ='May-20', y ='local authority: county / unitary (as of April 2021)', data = largest_May20)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Authorities with Highest Claimants of Aged 25-49 in 2020', size =15)
plt.show()

# %%
largest_May21 = df_25_49.nlargest(n=10, columns =['May-21'])
largest_May21
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     27895   22640
# 133                                               Kent     14620   10705
# 81                                               Essex     13775    9315
# 29                                          Lancashire     12195    8915
# 189                                       Glasgow City     13580   10335
# 21                                          Manchester     11990    8670
# 48                                               Leeds     14170   10860
# 82                                       Hertfordshire      9690    6820
# 45                                            Bradford     11095    9110
# 31                                           Liverpool     11325    8825
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    18005   17860   18535   20280   25365   45775   46615   38210
# ...

# %%
sns.barplot(x ='May-21', y ='local authority: county / unitary (as of April 2021)', data = largest_May21)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Authorities with Highest Claimants of Aged 25-49 in 2021', size =15)
plt.show()

# %%
largest_May22 = df_25_49.nlargest(n=10, columns =['May-22'])
largest_May22
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham     27895   22640
# 133                                               Kent     14620   10705
# 81                                               Essex     13775    9315
# 29                                          Lancashire     12195    8915
# 21                                          Manchester     11990    8670
# 189                                       Glasgow City     13580   10335
# 48                                               Leeds     14170   10860
# 45                                            Bradford     11095    9110
# 31                                           Liverpool     11325    8825
# 82                                       Hertfordshire      9690    6820
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66    18005   17860   18535   20280   25365   45775   46615   38210
# ...

# %%
sns.barplot(x ='May-22', y ='local authority: county / unitary (as of April 2021)', data = largest_May22)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Authorities with Highest Claimants of Aged 25-49 in 2022', size =15)
plt.show()

# %%
#claimants count aged 50+
data_aged50_plus= pd.read_csv('claimants count_local authority_nomis.csv', skiprows=1040, nrows=217, na_values=('#','!'))
data_aged50_plus
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 0                                           Darlington       595     485
# 1                                        County Durham      2335    1825
# 2                                           Hartlepool       655     560
# 3                                        Middlesbrough      1005     830
# 4                                       Northumberland      1400    1180
# ..                                                 ...       ...     ...
# 212                            Lisburn and Castlereagh       530     505
# 213                                Mid and East Antrim       745     640
# 214                                         Mid Ulster       675     615
# 215                             Newry, Mourne and Down      1115    1120
# 216                                Ards and North Down       775     765
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# ...

# %%
#load the data into dataframe
df_50plus=pd.DataFrame(data_aged50_plus)
df_50plus
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 0                                           Darlington       595     485
# 1                                        County Durham      2335    1825
# 2                                           Hartlepool       655     560
# 3                                        Middlesbrough      1005     830
# 4                                       Northumberland      1400    1180
# ..                                                 ...       ...     ...
# 212                            Lisburn and Castlereagh       530     505
# 213                                Mid and East Antrim       745     640
# 214                                         Mid Ulster       675     615
# 215                             Newry, Mourne and Down      1115    1120
# 216                                Ards and North Down       775     765
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# ...

# %%
# Plot the data in histogram
df_50plus.hist(bins= 50, figsize=(15,15))
plt.show()

# %%
# Mean values of the data
df_50plus.mean(numeric_only=True)
# Out:
# May-13    1183.018433
# May-14     962.649770
# May-15     793.755760
# May-16     848.248848
# May-17     943.778802
# May-18    1095.599078
# May-19    1332.534562
# May-20    2819.608295
# May-21    2720.760369
# May-22    1831.474654
# dtype: float64

# %%
largest_May13 = df_50plus.nlargest(n=10, columns =['May-13'])
largest_May13
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham      7485    6555
# 133                                               Kent      5025    4015
# 81                                               Essex      4555    3575
# 189                                       Glasgow City      3715    3130
# 29                                          Lancashire      3630    2980
# 48                                               Leeds      3590    3000
# 82                                       Hertfordshire      3420    2740
# 83                                             Norfolk      3120    2335
# 31                                           Liverpool      2985    2475
# 132                                          Hampshire      2950    2075
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     5670    6350    7160    8770   11090   16540   18280   15255
# ...

# %%
sns.barplot(x ='May-13', y ='local authority: county / unitary (as of April 2021)', data = largest_May13)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Authorities with Highest Claimants Count Aged 50+ in 2013', size =15)
plt.show()

# %%
largest_May14 = df_50plus.nlargest(n=10, columns =['May-14'])
largest_May14
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham      7485    6555
# 133                                               Kent      5025    4015
# 81                                               Essex      4555    3575
# 189                                       Glasgow City      3715    3130
# 48                                               Leeds      3590    3000
# 29                                          Lancashire      3630    2980
# 82                                       Hertfordshire      3420    2740
# 45                                            Bradford      2880    2730
# 208                                            Belfast      2535    2495
# 31                                           Liverpool      2985    2475
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     5670    6350    7160    8770   11090   16540   18280   15255
# ...

# %%
sns.barplot(x ='May-14', y ='local authority: county / unitary (as of April 2021)', data = largest_May14)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants Count Aged 50+ in 2014', size =15)
plt.show()

# %%
largest_May15 = df_50plus.nlargest(n=10, columns =['May-15'])
largest_May15
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham      7485    6555
# 133                                               Kent      5025    4015
# 189                                       Glasgow City      3715    3130
# 81                                               Essex      4555    3575
# 29                                          Lancashire      3630    2980
# 48                                               Leeds      3590    3000
# 31                                           Liverpool      2985    2475
# 82                                       Hertfordshire      3420    2740
# 45                                            Bradford      2880    2730
# 208                                            Belfast      2535    2495
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     5670    6350    7160    8770   11090   16540   18280   15255
# ...

# %%
sns.barplot(x ='May-15', y ='local authority: county / unitary (as of April 2021)', data = largest_May15)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Authorities with Highest Claimants Count Aged 50+ in 2015', size =15)
plt.show()

# %%
largest_May16 = df_50plus.nlargest(n=10, columns =['May-16'])
largest_May16
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham      7485    6555
# 133                                               Kent      5025    4015
# 81                                               Essex      4555    3575
# 29                                          Lancashire      3630    2980
# 189                                       Glasgow City      3715    3130
# 48                                               Leeds      3590    3000
# 31                                           Liverpool      2985    2475
# 82                                       Hertfordshire      3420    2740
# 21                                          Manchester      2800    2280
# 45                                            Bradford      2880    2730
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     5670    6350    7160    8770   11090   16540   18280   15255
# ...

# %%
sns.barplot(x ='May-16', y ='local authority: county / unitary (as of April 2021)', data = largest_May16)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants Count Aged 50+ in 2016', size =15)
plt.show()

# %%
largest_May17 = df_50plus.nlargest(n=10, columns =['May-17'])
largest_May17
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham      7485    6555
# 133                                               Kent      5025    4015
# 29                                          Lancashire      3630    2980
# 81                                               Essex      4555    3575
# 189                                       Glasgow City      3715    3130
# 48                                               Leeds      3590    3000
# 31                                           Liverpool      2985    2475
# 82                                       Hertfordshire      3420    2740
# 104                                            Croydon      1750    1335
# 21                                          Manchester      2800    2280
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     5670    6350    7160    8770   11090   16540   18280   15255
# ...

# %%
sns.barplot(x ='May-17', y ='local authority: county / unitary (as of April 2021)', data = largest_May17)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants Count Aged 50+ in 2017', size =15)
plt.show()

# %%
largest_May18 = df_50plus.nlargest(n=10, columns =['May-18'])
largest_May18
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham      7485    6555
# 133                                               Kent      5025    4015
# 29                                          Lancashire      3630    2980
# 81                                               Essex      4555    3575
# 189                                       Glasgow City      3715    3130
# 82                                       Hertfordshire      3420    2740
# 48                                               Leeds      3590    3000
# 31                                           Liverpool      2985    2475
# 1                                        County Durham      2335    1825
# 21                                          Manchester      2800    2280
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     5670    6350    7160    8770   11090   16540   18280   15255
# ...

# %%
sns.barplot(x ='May-18', y ='local authority: county / unitary (as of April 2021)', data = largest_May18)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants Count Aged 50+ in 2018', size =15)
plt.show()

# %%
largest_May19 = df_50plus.nlargest(n=10, columns =['May-19'])
largest_May19
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham      7485    6555
# 133                                               Kent      5025    4015
# 81                                               Essex      4555    3575
# 29                                          Lancashire      3630    2980
# 189                                       Glasgow City      3715    3130
# 82                                       Hertfordshire      3420    2740
# 48                                               Leeds      3590    3000
# 21                                          Manchester      2800    2280
# 45                                            Bradford      2880    2730
# 31                                           Liverpool      2985    2475
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     5670    6350    7160    8770   11090   16540   18280   15255
# ...

# %%
sns.barplot(x ='May-19', y ='local authority: county / unitary (as of April 2021)', data = largest_May19)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants Count Aged 50+ in 2019', size =15)
plt.show()

# %%
largest_May20 = df_50plus.nlargest(n=10, columns =['May-20'])
largest_May20
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham      7485    6555
# 133                                               Kent      5025    4015
# 81                                               Essex      4555    3575
# 29                                          Lancashire      3630    2980
# 82                                       Hertfordshire      3420    2740
# 132                                          Hampshire      2950    2075
# 189                                       Glasgow City      3715    3130
# 135                                             Surrey      2365    1690
# 83                                             Norfolk      3120    2335
# 136                                        West Sussex      2135    1575
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     5670    6350    7160    8770   11090   16540   18280   15255
# ...

# %%
sns.barplot(x ='May-20', y ='local authority: county / unitary (as of April 2021)', data = largest_May20)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Counties with Highest Claimants Count Aged 50+ in 2020', size =15)
plt.show()

# %%
largest_May21 = df_50plus.nlargest(n=10, columns =['May-21'])
largest_May21
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham      7485    6555
# 133                                               Kent      5025    4015
# 81                                               Essex      4555    3575
# 29                                          Lancashire      3630    2980
# 82                                       Hertfordshire      3420    2740
# 132                                          Hampshire      2950    2075
# 189                                       Glasgow City      3715    3130
# 48                                               Leeds      3590    3000
# 135                                             Surrey      2365    1690
# 136                                        West Sussex      2135    1575
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     5670    6350    7160    8770   11090   16540   18280   15255
# ...

# %%
sns.barplot(x ='May-21', y ='local authority: county / unitary (as of April 2021)', data = largest_May21)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Authorities with Highest Claimants Count Aged 50+ in 2021', size =15)
plt.show()

# %%
largest_May22 = df_50plus.nlargest(n=10, columns =['May-22'])
largest_May22
# Out:
#     local authority: county / unitary (as of April 2021)  May-13  May-14  \
# 66                                          Birmingham      7485    6555
# 133                                               Kent      5025    4015
# 81                                               Essex      4555    3575
# 29                                          Lancashire      3630    2980
# 45                                            Bradford      2880    2730
# 189                                       Glasgow City      3715    3130
# 48                                               Leeds      3590    3000
# 132                                          Hampshire      2950    2075
# 21                                          Manchester      2800    2280
# 82                                       Hertfordshire      3420    2740
#
#      May-15  May-16  May-17  May-18  May-19  May-20  May-21  May-22
# 66     5670    6350    7160    8770   11090   16540   18280   15255
# ...

# %%
sns.barplot(x ='May-22', y ='local authority: county / unitary (as of April 2021)', data = largest_May22)
plt.xlabel('Number of Claimants', size=13)
plt.ylabel('Local Authorities/Counties', size=13)
plt.title('Ten Local Authorities with Highest Claimants Count Aged 50+ in 2022', size =15)
plt.show()

# %%
#Unemployment rate aged 16-64
data_unemployed= pd.read_csv('Annual population survey.csv', skiprows =235, nrows =205, na_values=('#', '!', '~'))
data_unemployed
# Out:
#     local authority: county / unitary (as of April 2019) Numerator  \
# 0                                           Darlington        4200
# 1                                        County Durham       24300
# 2                                           Hartlepool        6600
# 3                                        Middlesbrough        8100
# 4                                       Northumberland        8600
# ..                                                 ...         ...
# 200                                     South Ayrshire        3800
# 201                                  South Lanarkshire       14700
# 202                                           Stirling        3400
# 203                                West Dunbartonshire        4300
# 204                                       West Lothian        6900
#
#     Denominator Jan 2013-Dec 2013 Numerator.1 Denominator.1 Jan 2014-Dec 2014  \
# 0         52100                 8        4100         51200                 8
# ...

# %%
# load the data into dataframe
df = pd.DataFrame(data_unemployed)
df
# Out:
#     local authority: county / unitary (as of April 2019) Numerator  \
# 0                                           Darlington        4200
# 1                                        County Durham       24300
# 2                                           Hartlepool        6600
# 3                                        Middlesbrough        8100
# 4                                       Northumberland        8600
# ..                                                 ...         ...
# 200                                     South Ayrshire        3800
# 201                                  South Lanarkshire       14700
# 202                                           Stirling        3400
# 203                                West Dunbartonshire        4300
# 204                                       West Lothian        6900
#
#     Denominator Jan 2013-Dec 2013 Numerator.1 Denominator.1 Jan 2014-Dec 2014  \
# 0         52100                 8        4100         51200                 8
# ...

# %%
#Trying to get nlarge value but it has dtype error
df['Jan 2013-Dec 2013']=pd.to_numeric(df['Jan 2013-Dec 2013'], errors = 'coerce')
unemployment_2013 = df.nlargest(10,['Jan 2013-Dec 2013'])
unemployment_2013
# Out:
#     local authority: county / unitary (as of April 2019) Numerator  \
# 65                                          Birmingham       75100
# 2                                           Hartlepool        6600
# 51                                           Leicester       24900
# 169                                      Blaenau Gwent        4900
# 193                                     North Ayrshire        9000
# 36                         Kingston upon Hull, City of       17500
# 98                                Barking and Dagenham       12800
# 11                                          Sunderland       18000
# 95                                       Tower Hamlets       20100
# 179                                        Dundee City        9200
#
#     Denominator  Jan 2013-Dec 2013 Numerator.1 Denominator.1  \
# 65       482700               15.6       57000        491600
# 2         42800               15.4        5000         41400
# ...

# %%
# Use explode and astype function to specify the column and plot the graph with float value
unemployment = unemployment_2013.explode('Jan 2013-Dec 2013')
unemployment['Jan 2013-Dec 2013'] = unemployment['Jan 2013-Dec 2013'].astype('float')
graph_unemployment_2013= sns.catplot( x='Jan 2013-Dec 2013', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2013-Dec 2013', data= unemployment_2013, kind='point').set (title = 'Ten Local Counties with Highest Unemployment Rates in 2013')
plt.xlabel('Unemployment Rates')
# Out:
# Text(0.5, 6.79999999999999, 'Unemployment Rates')

# %%
#Trying to get nlarge value of working class population but it has dtype error
df['Denominator']=pd.to_numeric(df['Denominator'], errors = 'coerce')
Working_popln_2013 = df.nlargest(10,'Denominator')
Working_popln_2013
# Out:
#     local authority: county / unitary (as of April 2019) Numerator  \
# 132                                               Kent       54400
# 80                                               Essex       45400
# 131                                          Hampshire       33600
# 81                                       Hertfordshire       31100
# 134                                             Surrey       27200
# 29                                          Lancashire       33300
# 65                                          Birmingham       75100
# 63                                       Staffordshire       19100
# 135                                        West Sussex       22800
# 82                                             Norfolk       27300
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1 Denominator.1  \
# 132     715900.0                7.6       38600        716000
# 80      695800.0                6.5       43100        691200
# ...

# %%
graph_working_popn2013= sns.catplot (x='Denominator', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2013-Dec 2013', data= Working_popln_2013, kind='bar' )
plt.title('Top 10 Largest Working Poulation in 2013 and  their Unemployment Rate', size =13)
plt.xlabel('Working Population in 2013', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Working Population in 2013')

# %%
#Trying to get nlarge value but it has dtype error
df['Numerator']=pd.to_numeric(df['Numerator'], errors = 'coerce')
unempl_popln_2013= df.nlargest(10,'Numerator')
unempl_popln_2013
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 65                                          Birmingham      75100.0
# 132                                               Kent      54400.0
# 80                                               Essex      45400.0
# 48                                               Leeds      35900.0
# 131                                          Hampshire      33600.0
# 29                                          Lancashire      33300.0
# 81                                       Hertfordshire      31100.0
# 44                                           Sheffield      29200.0
# 188                                       Glasgow City      28700.0
# 82                                             Norfolk      27300.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1  Denominator.1  \
# 65      482700.0               15.6       57000       491600.0
# 132     715900.0                7.6       38600       716000.0
# ...

# %%
graph_unempl_popln2013= sns.catplot (x='Numerator', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2013-Dec 2013', data= unempl_popln_2013, kind='bar' )
plt.title('Top 10 Unemployed Working Population in 2013 and  their Unemployment Rate', size =13)
plt.xlabel('Unemployed Working Population in 2013', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Unemployed Working Population in 2013')

# %%
#Trying to get nlarge value but it has dtype error
df['Jan 2014-Dec 2014']=pd.to_numeric(df['Jan 2014-Dec 2014'], errors = 'coerce')
unemployment_2014 = df.nlargest(10,['Jan 2014-Dec 2014'])
unemployment_2014
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 3                                        Middlesbrough       8100.0
# 71                                       Wolverhampton      14200.0
# 31                                           Liverpool      27100.0
# 169                                      Blaenau Gwent       4900.0
# 36                         Kingston upon Hull, City of      17500.0
# 2                                           Hartlepool       6600.0
# 65                                          Birmingham      75100.0
# 98                                Barking and Dagenham      12800.0
# 52                                          Nottingham      17400.0
# 33                                          St. Helens       6100.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1 Denominator.1  \
# 3        61900.0               13.1        8700         63400
# 71      114100.0               12.4       14500        114900
# ...

# %%
unemployment = unemployment_2014.explode('Jan 2014-Dec 2014')
unemployment['Jan 2014-Dec 2014'] = unemployment['Jan 2014-Dec 2014'].astype('float')
graph_unemployment_2014= sns.catplot( x='Jan 2014-Dec 2014', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2014-Dec 2014', data= unemployment_2014, kind='point').set(title = 'Ten Local Counties with Highest Unemployment Rates in 2014')
plt.xlabel('Unemployment Rates')
# Out:
# Text(0.5, 6.79999999999999, 'Unemployment Rates')

# %%
#Trying to get nlarge value but it has dtype error
df['Jan 2015-Dec 2015']=pd.to_numeric(df['Jan 2015-Dec 2015'], errors = 'coerce')
unemployment_2015 = df.nlargest(10,['Jan 2015-Dec 2015'])
unemployment_2015
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 3                                        Middlesbrough       8100.0
# 71                                       Wolverhampton      14200.0
# 193                                     North Ayrshire       9000.0
# 98                                Barking and Dagenham      12800.0
# 2                                           Hartlepool       6600.0
# 45                                            Bradford      26900.0
# 51                                           Leicester      24900.0
# 169                                      Blaenau Gwent       4900.0
# 8                                  Newcastle upon Tyne      14500.0
# 52                                          Nottingham      17400.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1 Denominator.1  \
# 3        61900.0               13.1        8700         63400
# 71      114100.0               12.4       14500        114900
# ...

# %%
unemployment = unemployment_2015.explode('Jan 2015-Dec 2015')
unemployment['Jan 2015-Dec 2015'] = unemployment['Jan 2013-Dec 2013'].astype('float')
graph_unemployment_2015= sns.catplot( x='Jan 2015-Dec 2015', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2015-Dec 2015', data= unemployment_2015, kind='point').set(title = 'Ten Local Counties with Highest Unemployment Rates in 2015')
plt.xlabel('Unemployment Rates')
# Out:
# Text(0.5, 6.79999999999999, 'Unemployment Rates')

# %%
# Find the ten largest unemployment rate counties in 2016
df['Jan 2016-Dec 2016']=pd.to_numeric(df['Jan 2016-Dec 2016'], errors = 'coerce')
unemployment_2016 = df.nlargest(10,['Jan 2016-Dec 2016'])
unemployment_2016
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 95                                       Tower Hamlets      20100.0
# 193                                     North Ayrshire       9000.0
# 2                                           Hartlepool       6600.0
# 65                                          Birmingham      75100.0
# 68                                            Sandwell      17100.0
# 24                                             Salford      14800.0
# 90                              Kensington and Chelsea       5500.0
# 10                                      South Tyneside       8300.0
# 71                                       Wolverhampton      14200.0
# 21                                          Manchester      25400.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1 Denominator.1  \
# 95      146800.0               13.7       16500        159800
# 193      60200.0               15.0        4600         63800
# ...

# %%
Unemployment = unemployment_2016.explode('Jan 2016-Dec 2016')
unemployment['Jan 2016-Dec 2016'] = unemployment['Jan 2016-Dec 2016'].astype('float')
graph_unemployment_2016= sns.catplot( x='Jan 2016-Dec 2016', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2016-Dec 2016', data= unemployment_2016, kind='point').set(title = 'Ten Local Counties with Highest Unemployment Rates in 2016')
plt.xlabel('Unemployment Rates')
# Out:
# Text(0.5, 6.79999999999999, 'Unemployment Rates')

# %%
#Trying to get nlarge value but it has dtype error
df['Jan 2017-Dec 2017']=pd.to_numeric(df['Jan 2017-Dec 2017'], errors = 'coerce')
unemployment_2017 = df.nlargest(10,['Jan 2017-Dec 2017'])
unemployment_2017
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 2                                           Hartlepool       6600.0
# 95                                       Tower Hamlets      20100.0
# 98                                Barking and Dagenham      12800.0
# 65                                          Birmingham      75100.0
# 68                                            Sandwell      17100.0
# 10                                      South Tyneside       8300.0
# 90                              Kensington and Chelsea       5500.0
# 52                                          Nottingham      17400.0
# 110                                           Hounslow      11000.0
# 71                                       Wolverhampton      14200.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1 Denominator.1  \
# 2        42800.0               15.4        5000         41400
# 95      146800.0               13.7       16500        159800
# ...

# %%
Unemployment = unemployment_2017.explode('Jan 2017-Dec 2017')
unemployment['Jan 2017-Dec 2017'] = unemployment['Jan 2017-Dec 2017'].astype('float')
graph_unemployment_2017= sns.catplot( x='Jan 2017-Dec 2017', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2017-Dec 2017', data= unemployment_2017, kind='point').set(title = 'Ten Local Counties with Highest Unemployment Rates in 2017')
plt.xlabel('Unemployment Rates')
# Out:
# Text(0.5, 6.79999999999999, 'Unemployment Rates')

# %%
#Trying to get nlarge value but it has dtype error
df['Jan 2018-Dec 2018']=pd.to_numeric(df['Jan 2018-Dec 2018'], errors = 'coerce')
unemployment_2018 = df.nlargest(10,['Jan 2018-Dec 2018'])
unemployment_2018
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 2                                           Hartlepool       6600.0
# 3                                        Middlesbrough       8100.0
# 90                              Kensington and Chelsea       5500.0
# 65                                          Birmingham      75100.0
# 118                                  Brighton and Hove      11300.0
# 71                                       Wolverhampton      14200.0
# 13                                           Blackpool       5300.0
# 10                                      South Tyneside       8300.0
# 11                                          Sunderland      18000.0
# 61                                      Stoke-on-Trent      10600.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1 Denominator.1  \
# 2        42800.0               15.4        5000         41400
# 3        61900.0               13.1        8700         63400
# ...

# %%
Unemployment = unemployment_2018.explode('Jan 2018-Dec 2018')
unemployment['Jan 2018-Dec 2018'] = unemployment['Jan 2018-Dec 2018'].astype('float')
graph_unemployment_2018= sns.catplot( x='Jan 2018-Dec 2018', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2018-Dec 2018', data= unemployment_2018, kind='point').set(title = 'Ten Local Counties with Highest Unemployment Rates in 2018')
plt.xlabel('Unemployment Rates')
# Out:
# Text(0.5, 6.79999999999999, 'Unemployment Rates')

# %%
#Trying to get nlarge value but it has dtype error
df['Jan 2019-Dec 2019']=pd.to_numeric(df['Jan 2019-Dec 2019'], errors = 'coerce')
unemployment_2019 = df.nlargest(10,['Jan 2019-Dec 2019'])
unemployment_2019
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 65                                          Birmingham      75100.0
# 10                                      South Tyneside       8300.0
# 52                                          Nottingham      17400.0
# 2                                           Hartlepool       6600.0
# 36                         Kingston upon Hull, City of      17500.0
# 105                                            Enfield      12500.0
# 3                                        Middlesbrough       8100.0
# 19                                              Bolton      13800.0
# 42                                           Doncaster      14500.0
# 11                                          Sunderland      18000.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1 Denominator.1  \
# 65      482700.0               15.6       57000        491600
# 10       71200.0               11.6        6800         71800
# ...

# %%
Unemployment = unemployment_2019.explode('Jan 2019-Dec 2019')
unemployment['Jan 2019-Dec 2019'] = unemployment['Jan 2019-Dec 2019'].astype('float')
graph_unemployment_2019= sns.catplot( x='Jan 2019-Dec 2019', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2019-Dec 2019', data= unemployment_2019, kind='point').set(title = 'Ten Local Counties with Highest Unemployment Rates in 2019')
plt.xlabel('Unemployment Rates')
# Out:
# Text(0.5, 6.79999999999999, 'Unemployment Rates')

# %%
#Trying to get nlarge value but it has dtype error
df['Jan 2020-Dec 2020']=pd.to_numeric(df['Jan 2020-Dec 2020'], errors = 'coerce')
unemployment_2020 = df.nlargest(10,['Jan 2020-Dec 2020'])
unemployment_2020
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 97                                         Westminster       7100.0
# 116                                     Waltham Forest      10500.0
# 98                                Barking and Dagenham      12800.0
# 109                                         Hillingdon      12400.0
# 65                                          Birmingham      75100.0
# 91                                             Lambeth      15700.0
# 21                                          Manchester      25400.0
# 42                                           Doncaster      14500.0
# 107                                             Harrow      11600.0
# 2                                           Hartlepool       6600.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1 Denominator.1  \
# 97      114900.0                6.1        6900        115700
# 116     137000.0                7.7       12200        134200
# ...

# %%
Unemployment = unemployment_2020.explode('Jan 2020-Dec 2020')
unemployment['Jan 2020-Dec 2020'] = unemployment['Jan 2013-Dec 2013'].astype('float')
graph_unemployment_2020= sns.catplot( x='Jan 2020-Dec 2020', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2020-Dec 2020', data= unemployment_2020, kind='point').set(title = 'Ten Local Counties with Highest Unemployment Rates in 2020')
plt.xlabel('Unemployment Rates')
# Out:
# Text(0.5, 6.79999999999999, 'Unemployment Rates')

# %%
#Trying to get nlarge value but it has dtype error
df['Jan 2021-Dec 2021']=pd.to_numeric(df['Jan 2021-Dec 2021'], errors = 'coerce')
unemployment_2021 = df.nlargest(10,['Jan 2021-Dec 2021'])
unemployment_2021
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 65                                          Birmingham      75100.0
# 195                                     Orkney Islands          NaN
# 3                                        Middlesbrough       8100.0
# 21                                          Manchester      25400.0
# 106                                          Greenwich      14000.0
# 113                                          Redbridge      15300.0
# 101                                              Brent      17700.0
# 99                                              Barnet      10600.0
# 198                                   Scottish Borders       2000.0
# 2                                           Hartlepool       6600.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1 Denominator.1  \
# 65      482700.0               15.6       57000        491600
# 195      10900.0                NaN         NaN         11900
# ...

# %%
Unemployment = unemployment_2021.explode('Jan 2021-Dec 2021')
unemployment['Jan 2021-Dec 2021'] = unemployment['Jan 2021-Dec 2021'].astype('float')
graph_unemployment_2021= sns.catplot( x='Jan 2021-Dec 2021', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2021-Dec 2021', data= unemployment_2021, kind='point').set(title = 'Ten Local Counties with Highest Unemployment Rates in 2021')
plt.xlabel('Unemployment Rates')
# Out:
# Text(0.5, 6.79999999999999, 'Unemployment Rates')

# %%
#Trying to get nlarge value of working class population but it has dtype error
df['Denominator.1']=pd.to_numeric(df['Denominator.1'], errors = 'coerce')
Working_popln_2014 = df.nlargest(10,'Denominator.1')
Working_popln_2014
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 132                                               Kent      54400.0
# 80                                               Essex      45400.0
# 131                                          Hampshire      33600.0
# 81                                       Hertfordshire      31100.0
# 134                                             Surrey      27200.0
# 29                                          Lancashire      33300.0
# 65                                          Birmingham      75100.0
# 63                                       Staffordshire      19100.0
# 82                                             Norfolk      27300.0
# 135                                        West Sussex      22800.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1  Denominator.1  \
# 132     715900.0                7.6       38600       716000.0
# 80      695800.0                6.5       43100       691200.0
# ...

# %%
graph_working_popln_2014= sns.catplot (x='Denominator', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2014-Dec 2014', data= Working_popln_2014, kind='bar' )
plt.title('Top 10 Largest Working Poulation in 2014 and  their Unemployment Rate', size =13)
plt.xlabel('Working Population in 2014', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Working Population in 2014')

# %%
#Trying to get nlarge value of working class population but it has dtype error
df['Denominator.2']=pd.to_numeric(df['Denominator.2'], errors = 'coerce')
Working_popln_2015 = df.nlargest(10,'Denominator.2')
Working_popln_2015
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 132                                               Kent      54400.0
# 80                                               Essex      45400.0
# 131                                          Hampshire      33600.0
# 81                                       Hertfordshire      31100.0
# 134                                             Surrey      27200.0
# 29                                          Lancashire      33300.0
# 65                                          Birmingham      75100.0
# 63                                       Staffordshire      19100.0
# 82                                             Norfolk      27300.0
# 48                                               Leeds      35900.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1  Denominator.1  \
# 132     715900.0                7.6       38600       716000.0
# 80      695800.0                6.5       43100       691200.0
# ...

# %%
graph_working_popn2015= sns.catplot (x='Denominator', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2015-Dec 2015', data= Working_popln_2015, kind='bar' )
plt.title('Top 10 Largest Working Poulation in 2015 and  their Unemployment Rate', size =13)
plt.xlabel('Working Population in 2015', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Working Population in 2015')

# %%
#Trying to get nlarge value of working class population but it has dtype error
df['Denominator.3']=pd.to_numeric(df['Denominator.3'], errors = 'coerce')
Working_popln_2016 = df.nlargest(10,'Denominator.3')
Working_popln_2016
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 132                                               Kent      54400.0
# 80                                               Essex      45400.0
# 131                                          Hampshire      33600.0
# 81                                       Hertfordshire      31100.0
# 134                                             Surrey      27200.0
# 29                                          Lancashire      33300.0
# 65                                          Birmingham      75100.0
# 63                                       Staffordshire      19100.0
# 82                                             Norfolk      27300.0
# 135                                        West Sussex      22800.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1  Denominator.1  \
# 132     715900.0                7.6       38600       716000.0
# 80      695800.0                6.5       43100       691200.0
# ...

# %%
graph_working_popn2016= sns.catplot (x='Denominator', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2016-Dec 2016', data= Working_popln_2016, kind='bar' )
plt.title('Top 10 Largest Working Poulation in 2016 and  their Unemployment Rate', size =13)
plt.xlabel('Working Population in 2016', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Working Population in 2016')

# %%
#Trying to get nlarge value of working class population but it has dtype error
df['Denominator.4']=pd.to_numeric(df['Denominator.4'], errors = 'coerce')
Working_popln_2017 = df.nlargest(10,'Denominator.4')
Working_popln_2017
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 132                                               Kent      54400.0
# 80                                               Essex      45400.0
# 131                                          Hampshire      33600.0
# 81                                       Hertfordshire      31100.0
# 134                                             Surrey      27200.0
# 29                                          Lancashire      33300.0
# 65                                          Birmingham      75100.0
# 63                                       Staffordshire      19100.0
# 135                                        West Sussex      22800.0
# 82                                             Norfolk      27300.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1  Denominator.1  \
# 132     715900.0                7.6       38600       716000.0
# 80      695800.0                6.5       43100       691200.0
# ...

# %%
graph_working_popn2017= sns.catplot (x='Denominator', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2017-Dec 2017', data= Working_popln_2017, kind='bar' )
plt.title('Top 10 Largest Working Poulation in 2017 and  their Unemployment Rate', size =13)
plt.xlabel('Working Population in 2017', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Working Population in 2017')

# %%
#Trying to get nlarge value of working class population but it has dtype error
df['Denominator.5']=pd.to_numeric(df['Denominator.5'], errors = 'coerce')
Working_popln_2018 = df.nlargest(10,'Denominator.5')
Working_popln_2018
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 132                                               Kent      54400.0
# 80                                               Essex      45400.0
# 131                                          Hampshire      33600.0
# 81                                       Hertfordshire      31100.0
# 134                                             Surrey      27200.0
# 29                                          Lancashire      33300.0
# 65                                          Birmingham      75100.0
# 63                                       Staffordshire      19100.0
# 82                                             Norfolk      27300.0
# 135                                        West Sussex      22800.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1  Denominator.1  \
# 132     715900.0                7.6       38600       716000.0
# 80      695800.0                6.5       43100       691200.0
# ...

# %%
graph_working_popn2018= sns.catplot (x='Denominator', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2018-Dec 2018', data= Working_popln_2018, kind='bar' )
plt.title('Top 10 Largest Working Poulation in 2018 and  their Unemployment Rate', size =13)
plt.xlabel('Working Population in 2018', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Working Population in 2018')

# %%
#Trying to get nlarge value of working class population but it has dtype error
df['Denominator.6']=pd.to_numeric(df['Denominator.6'], errors = 'coerce')
Working_popln_2019 = df.nlargest(10,'Denominator.6')
Working_popln_2019
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 132                                               Kent      54400.0
# 80                                               Essex      45400.0
# 131                                          Hampshire      33600.0
# 81                                       Hertfordshire      31100.0
# 134                                             Surrey      27200.0
# 29                                          Lancashire      33300.0
# 65                                          Birmingham      75100.0
# 63                                       Staffordshire      19100.0
# 135                                        West Sussex      22800.0
# 82                                             Norfolk      27300.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1  Denominator.1  \
# 132     715900.0                7.6       38600       716000.0
# 80      695800.0                6.5       43100       691200.0
# ...

# %%
graph_working_popn2019= sns.catplot (x='Denominator', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2019-Dec 2019', data= Working_popln_2019, kind='bar' )
plt.title('Top 10 Largest Working Poulation in 2019 and  their Unemployment Rate', size =13)
plt.xlabel('Working Population in 2019', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Working Population in 2019')

# %%
#Trying to get nlarge value of working class population but it has dtype error
df['Denominator.7']=pd.to_numeric(df['Denominator.7'], errors = 'coerce')
Working_popln_2020 = df.nlargest(10,'Denominator.7')
Working_popln_2020
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 132                                               Kent      54400.0
# 80                                               Essex      45400.0
# 131                                          Hampshire      33600.0
# 81                                       Hertfordshire      31100.0
# 134                                             Surrey      27200.0
# 29                                          Lancashire      33300.0
# 65                                          Birmingham      75100.0
# 48                                               Leeds      35900.0
# 63                                       Staffordshire      19100.0
# 82                                             Norfolk      27300.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1  Denominator.1  \
# 132     715900.0                7.6       38600       716000.0
# 80      695800.0                6.5       43100       691200.0
# ...

# %%
graph_working_popn2020= sns.catplot (x='Denominator', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2020-Dec 2020', data= Working_popln_2020, kind='bar' )
plt.title('Top 10 Largest Working Poulation in 2020 and  their Unemployment Rate', size =13)
plt.xlabel('Working Population in 2020', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Working Population in 2020')

# %%
#Trying to get nlarge value of working class population but it has dtype error
df['Denominator.8']=pd.to_numeric(df['Denominator.8'], errors = 'coerce')
Working_popln_2021 = df.nlargest(10,'Denominator.8')
Working_popln_2021
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 132                                               Kent      54400.0
# 80                                               Essex      45400.0
# 131                                          Hampshire      33600.0
# 81                                       Hertfordshire      31100.0
# 134                                             Surrey      27200.0
# 29                                          Lancashire      33300.0
# 65                                          Birmingham      75100.0
# 82                                             Norfolk      27300.0
# 63                                       Staffordshire      19100.0
# 135                                        West Sussex      22800.0
#
#      Denominator  Jan 2013-Dec 2013 Numerator.1  Denominator.1  \
# 132     715900.0                7.6       38600       716000.0
# 80      695800.0                6.5       43100       691200.0
# ...

# %%
graph_working_popn2021= sns.catplot (x='Denominator', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2021-Dec 2021', data= Working_popln_2021, kind='bar' )
plt.title('Top 10 Largest Working Poulation in 2021 and  their Unemployment Rate', size =13)
plt.xlabel('Working Population in 2021', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Working Population in 2021')

# %%
df['Numerator.1']=pd.to_numeric(df['Numerator.1'], errors = 'coerce')
unempl_popln_2014= df.nlargest(10,'Numerator.1')
unempl_popln_2014
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 65                                          Birmingham      75100.0
# 80                                               Essex      45400.0
# 132                                               Kent      54400.0
# 29                                          Lancashire      33300.0
# 48                                               Leeds      35900.0
# 188                                       Glasgow City      28700.0
# 134                                             Surrey      27200.0
# 44                                           Sheffield      29200.0
# 31                                           Liverpool      27100.0
# 81                                       Hertfordshire      31100.0
#
#      Denominator  Jan 2013-Dec 2013  Numerator.1  Denominator.1  \
# 65      482700.0               15.6      57000.0       491600.0
# 80      695800.0                6.5      43100.0       691200.0
# ...

# %%
graph_unempl_popln2014= sns.catplot (x='Numerator.1', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2014-Dec 2014', data= unempl_popln_2014, kind='bar' )
plt.title('Top 10 Unemployed Working Population in 2014 and  their Unemployment Rate', size =13)
plt.xlabel('Unemployed Working Population in 2014', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Unemployed Working Population in 2014')

# %%
df['Numerator.2']=pd.to_numeric(df['Numerator.2'], errors = 'coerce')
unempl_popln_2015= df.nlargest(10,'Numerator.2')
unempl_popln_2015
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 65                                          Birmingham      75100.0
# 132                                               Kent      54400.0
# 80                                               Essex      45400.0
# 131                                          Hampshire      33600.0
# 188                                       Glasgow City      28700.0
# 45                                            Bradford      26900.0
# 48                                               Leeds      35900.0
# 44                                           Sheffield      29200.0
# 21                                          Manchester      25400.0
# 29                                          Lancashire      33300.0
#
#      Denominator  Jan 2013-Dec 2013  Numerator.1  Denominator.1  \
# 65      482700.0               15.6      57000.0       491600.0
# 132     715900.0                7.6      38600.0       716000.0
# ...

# %%
graph_unempl_popln2015= sns.catplot (x='Numerator.2', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2015-Dec 2015', data= unempl_popln_2015, kind='bar' )
plt.title('Top 10 Unemployed Working Population in 2015 and  their Unemployment Rate', size =13)
plt.xlabel('Unemployed Working Population in 2015', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Unemployed Working Population in 2015')

# %%
df['Numerator.3']=pd.to_numeric(df['Numerator.3'], errors = 'coerce')
unempl_popln_2016= df.nlargest(10,'Numerator.3')
unempl_popln_2016
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 65                                          Birmingham      75100.0
# 132                                               Kent      54400.0
# 29                                          Lancashire      33300.0
# 80                                               Essex      45400.0
# 131                                          Hampshire      33600.0
# 81                                       Hertfordshire      31100.0
# 21                                          Manchester      25400.0
# 134                                             Surrey      27200.0
# 58                                     Nottinghamshire      26200.0
# 95                                       Tower Hamlets      20100.0
#
#      Denominator  Jan 2013-Dec 2013  Numerator.1  Denominator.1  \
# 65      482700.0               15.6      57000.0       491600.0
# 132     715900.0                7.6      38600.0       716000.0
# ...

# %%
graph_unempl_popln2013= sns.catplot (x='Numerator.3', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2016-Dec 2016', data= unempl_popln_2016, kind='bar' )
plt.title('Top 10 Unemployed Working Population in 2016 and  their Unemployment Rate', size =13)
plt.xlabel('Unemployed Working Population in 2016', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Unemployed Working Population in 2016')

# %%
df['Numerator.4']=pd.to_numeric(df['Numerator.4'], errors = 'coerce')
unempl_popln_2017= df.nlargest(10,'Numerator.4')
unempl_popln_2017
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 65                                          Birmingham      75100.0
# 80                                               Essex      45400.0
# 132                                               Kent      54400.0
# 29                                          Lancashire      33300.0
# 57                                    Northamptonshire      26400.0
# 81                                       Hertfordshire      31100.0
# 44                                           Sheffield      29200.0
# 48                                               Leeds      35900.0
# 63                                       Staffordshire      19100.0
# 82                                             Norfolk      27300.0
#
#      Denominator  Jan 2013-Dec 2013  Numerator.1  Denominator.1  \
# 65      482700.0               15.6      57000.0       491600.0
# 80      695800.0                6.5      43100.0       691200.0
# ...

# %%
graph_unempl_popln2017= sns.catplot (x='Numerator.4', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2017-Dec 2017', data= unempl_popln_2017, kind='bar' )
plt.title('Top 10 Unemployed Working Population in 2017 and  their Unemployment Rate', size =13)
plt.xlabel('Unemployed Working Population in 2017', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Unemployed Working Population in 2017')

# %%
df['Numerator.5']=pd.to_numeric(df['Numerator.5'], errors = 'coerce')
unempl_popln_2018= df.nlargest(10,'Numerator.5')
unempl_popln_2018
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 65                                          Birmingham      75100.0
# 132                                               Kent      54400.0
# 29                                          Lancashire      33300.0
# 80                                               Essex      45400.0
# 81                                       Hertfordshire      31100.0
# 58                                     Nottinghamshire      26200.0
# 131                                          Hampshire      33600.0
# 188                                       Glasgow City      28700.0
# 56                                        Lincolnshire      25400.0
# 55                                      Leicestershire      21000.0
#
#      Denominator  Jan 2013-Dec 2013  Numerator.1  Denominator.1  \
# 65      482700.0               15.6      57000.0       491600.0
# 132     715900.0                7.6      38600.0       716000.0
# ...

# %%
graph_unempl_popln2018= sns.catplot (x='Numerator.5', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2018-Dec 2018', data= unempl_popln_2018, kind='bar' )
plt.title('Top 10 Unemployed Working Population in 2018 and  their Unemployment Rate', size =13)
plt.xlabel('Unemployed Working Population in 2018', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Unemployed Working Population in 2018')

# %%
df['Numerator.6']=pd.to_numeric(df['Numerator.6'], errors = 'coerce')
unempl_popln_2019= df.nlargest(10,'Numerator.6')
unempl_popln_2019
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 65                                          Birmingham      75100.0
# 132                                               Kent      54400.0
# 81                                       Hertfordshire      31100.0
# 80                                               Essex      45400.0
# 131                                          Hampshire      33600.0
# 82                                             Norfolk      27300.0
# 21                                          Manchester      25400.0
# 29                                          Lancashire      33300.0
# 48                                               Leeds      35900.0
# 45                                            Bradford      26900.0
#
#      Denominator  Jan 2013-Dec 2013  Numerator.1  Denominator.1  \
# 65      482700.0               15.6      57000.0       491600.0
# 132     715900.0                7.6      38600.0       716000.0
# ...

# %%
graph_unempl_popln2019= sns.catplot (x='Numerator.6', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2019-Dec 2019', data= unempl_popln_2019, kind='bar' )
plt.title('Top 10 Unemployed Working Population in 2019 and  their Unemployment Rate', size =13)
plt.xlabel('Unemployed Working Population in 2019', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Unemployed Working Population in 2019')

# %%
df['Numerator.7']=pd.to_numeric(df['Numerator.7'], errors = 'coerce')
unempl_popln_2020= df.nlargest(10,'Numerator.7')
unempl_popln_2020
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 65                                          Birmingham      75100.0
# 132                                               Kent      54400.0
# 131                                          Hampshire      33600.0
# 134                                             Surrey      27200.0
# 21                                          Manchester      25400.0
# 80                                               Essex      45400.0
# 82                                             Norfolk      27300.0
# 63                                       Staffordshire      19100.0
# 54                                          Derbyshire      16200.0
# 81                                       Hertfordshire      31100.0
#
#      Denominator  Jan 2013-Dec 2013  Numerator.1  Denominator.1  \
# 65      482700.0               15.6      57000.0       491600.0
# 132     715900.0                7.6      38600.0       716000.0
# ...

# %%
graph_unempl_popln2020= sns.catplot (x='Numerator.7', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2020-Dec 2020', data= unempl_popln_2020, kind='bar' )
plt.title('Top 10 Unemployed Working Population in 2020 and  their Unemployment Rate', size =13)
plt.xlabel('Unemployed Working Population in 2020', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Unemployed Working Population in 2020')

# %%
df['Numerator.8']=pd.to_numeric(df['Numerator.8'], errors = 'coerce')
unempl_popln_2021= df.nlargest(10,'Numerator.8')
unempl_popln_2021
# Out:
#     local authority: county / unitary (as of April 2019)  Numerator  \
# 65                                          Birmingham      75100.0
# 132                                               Kent      54400.0
# 29                                          Lancashire      33300.0
# 81                                       Hertfordshire      31100.0
# 80                                               Essex      45400.0
# 21                                          Manchester      25400.0
# 131                                          Hampshire      33600.0
# 48                                               Leeds      35900.0
# 55                                      Leicestershire      21000.0
# 44                                           Sheffield      29200.0
#
#      Denominator  Jan 2013-Dec 2013  Numerator.1  Denominator.1  \
# 65      482700.0               15.6      57000.0       491600.0
# 132     715900.0                7.6      38600.0       716000.0
# ...

# %%
graph_unempl_popln2021= sns.catplot (x='Numerator.8', y ='local authority: county / unitary (as of April 2019)', hue= 'Jan 2021-Dec 2021', data= unempl_popln_2021, kind='bar' )
plt.title('Top 10 Unemployed Working Population in 2021 and  their Unemployment Rate', size =13)
plt.xlabel('Unemployed Working Population in 2021', size =13)
# Out:
# Text(0.5, 20.80000000000002, 'Unemployed Working Population in 2021')
